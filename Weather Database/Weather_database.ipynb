# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
from citipy import citipy
import json
import time
from scipy.stats import linregress
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | lindon
# Processing Record 2 | rikitea
# Processing Record 3 | sioux lookout
# Processing Record 4 | barcelos
# Processing Record 5 | ushuaia
# Processing Record 6 | yellowknife
# Processing Record 7 | bonthe
# Processing Record 8 | cheuskiny
# City not found. Skipping...
# Processing Record 9 | ponoka
# Processing Record 10 | saryshagan
# City not found. Skipping...
# Processing Record 11 | sayyan
# Processing Record 12 | kamaishi
# Processing Record 13 | emba
# Processing Record 14 | castro
# Processing Record 15 | ucluelet
# Processing Record 16 | carutapera
# Processing Record 17 | kodiak
# Processing Record 18 | ayan
# Processing Record 19 | butaritari
# Processing Record 20 | bethel
# Processing Record 21 | carnarvon
# Processing Record 22 | barrow
# Processing Record 23 | komsomolskiy
# Processing Record 24 | bluff
# Processing Record 25 | hualmay
# Processing Record 26 | atuona
# Processing Record 27 | fortuna
# Processing Record 28 | chokurdakh
# Processing Record 29 | punta arenas
# Processing Record 30 | taolanaro
# City not found. Skipping...
# Processing Record 31 | araguacu
# Processing Record 32 | zhigansk
# Processing Record 33 | clyde river
# Processing Record 34 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 | margate
# Processing Record 36 | hobart
# Processing Record 37 | lebu
# Processing Record 38 | hermanus
# Processing Record 39 | thompson
# Processing Record 40 | hami
# Processing Record 41 | orchard homes
# Processing Record 42 | kadykchan
# City not found. Skipping...
# Processing Record 43 | qaanaaq
# Processing Record 44 | avarua
# Processing Record 45 | taltal
# Processing Record 46 | pangai
# Processing Record 47 | tlacojalpan
# Processing Record 48 | savalou
# Processing Record 49 | jabiru
# City not found. Skipping...
# Processing Record 50 | druzhinino
# Processing Record 51 | fernandez
# Processing Record 52 | wagar
# Processing Record 53 | flinders
# Processing Record 54 | albany
# Processing Record 55 | belushya guba
# City not found. Skipping...
# Processing Record 56 | dikson
# Processing Record 57 | san patricio
# Processing Record 58 | la rochelle
# Processing Record 59 | mount isa
# Processing Record 60 | luderitz
# Processing Record 61 | aguimes
# Processing Record 62 | padang
# Processing Record 63 | vaini
# Processing Record 64 | chulumani
# Processing Record 65 | jamestown
# Processing Record 66 | kemijarvi
# Processing Record 67 | mataura
# Processing Record 68 | faanui
# Processing Record 69 | rundu
# Processing Record 70 | hilo
# Processing Record 71 | vardo
# Processing Record 72 | koumac
# Processing Record 73 | chisec
# Processing Record 74 | mahebourg
# Processing Record 75 | cherskiy
# Processing Record 76 | saint-pierre
# Processing Record 77 | half moon bay
# Processing Record 78 | busselton
# Processing Record 79 | esso
# Processing Record 80 | russell
# Processing Record 81 | bafq
# Processing Record 82 | port-gentil
# Processing Record 83 | sao filipe
# Processing Record 84 | bodden town
# Processing Record 85 | tallya
# Processing Record 86 | kieta
# Processing Record 87 | arraial do cabo
# Processing Record 88 | tautira
# Processing Record 89 | muroto
# Processing Record 90 | labrea
# Processing Record 91 | strezhevoy
# Processing Record 92 | souillac
# Processing Record 93 | road town
# Processing Record 94 | nikolskoye
# Processing Record 95 | empangeni
# Processing Record 96 | carroll
# Processing Record 97 | port hardy
# Processing Record 98 | nizhneyansk
# City not found. Skipping...
# Processing Record 99 | fairbanks
# Processing Record 100 | barentsburg
# City not found. Skipping...
# Processing Record 101 | poya
# Processing Record 102 | tomatlan
# Processing Record 103 | ostrovnoy
# Processing Record 104 | suntar
# Processing Record 105 | portland
# Processing Record 106 | kidal
# Processing Record 107 | talawdi
# City not found. Skipping...
# Processing Record 108 | orlik
# Processing Record 109 | nouakchott
# Processing Record 110 | clinton
# Processing Record 111 | narsaq
# Processing Record 112 | maningrida
# Processing Record 113 | moose factory
# Processing Record 114 | chase
# Processing Record 115 | port elizabeth
# Processing Record 116 | umzimvubu
# City not found. Skipping...
# Processing Record 117 | hauge
# Processing Record 118 | bundaberg
# Processing Record 119 | saleaula
# City not found. Skipping...
# Processing Record 120 | ploemeur
# Processing Record 121 | amderma
# City not found. Skipping...
# Processing Record 122 | alugan
# Processing Record 123 | ponta do sol
# Processing Record 124 | sumbawa
# City not found. Skipping...
# Processing Record 125 | sistranda
# Processing Record 126 | palmer
# Processing Record 127 | chingola
# Processing Record 128 | codrington
# Processing Record 129 | kristiansund
# Processing Record 130 | victoria
# Processing Record 131 | bredasdorp
# Processing Record 132 | khonuu
# City not found. Skipping...
# Processing Record 133 | turukhansk
# Processing Record 134 | saint george
# Processing Record 135 | berlin
# Processing Record 136 | goure
# Processing Record 137 | airai
# Processing Record 138 | murdochville
# Processing Record 139 | mezen
# Processing Record 140 | saskylakh
# Processing Record 141 | grand gaube
# Processing Record 142 | port alfred
# Processing Record 143 | opuwo
# Processing Record 144 | gangotri
# City not found. Skipping...
# Processing Record 145 | alvaraes
# Processing Record 146 | takoradi
# Processing Record 147 | lompoc
# Processing Record 148 | katangli
# Processing Record 149 | cabo san lucas
# Processing Record 150 | barbar
# City not found. Skipping...
# Processing Record 151 | ullapool
# Processing Record 152 | funtua
# Processing Record 153 | meadow lake
# Processing Record 154 | troitsko-pechorsk
# Processing Record 155 | tulle
# Processing Record 156 | banda aceh
# Processing Record 157 | masallatah
# Processing Record 158 | milkovo
# Processing Record 159 | cape town
# Processing Record 160 | lake city
# Processing Record 161 | bandarbeyla
# Processing Record 162 | mys shmidta
# City not found. Skipping...
# Processing Record 163 | mount gambier
# Processing Record 164 | himora
# City not found. Skipping...
# Processing Record 165 | bambous virieux
# Processing Record 166 | mayumba
# Processing Record 167 | constitucion
# Processing Record 168 | puerto ayora
# Processing Record 169 | lorengau
# Processing Record 170 | hurricane
# Processing Record 171 | tasiilaq
# Processing Record 172 | yarmouth
# Processing Record 173 | karamay
# City not found. Skipping...
# Processing Record 174 | kapaa
# Processing Record 175 | jining
# Processing Record 176 | kaitangata
# Processing Record 177 | joao pinheiro
# Processing Record 178 | henties bay
# Processing Record 179 | ekhabi
# Processing Record 180 | fukue
# Processing Record 181 | alegrete
# Processing Record 182 | east london
# Processing Record 183 | maloshuyka
# City not found. Skipping...
# Processing Record 184 | yar-sale
# Processing Record 185 | dunedin
# Processing Record 186 | muros
# Processing Record 187 | chikhli
# Processing Record 188 | dejen
# Processing Record 189 | cap malheureux
# Processing Record 190 | saldanha
# Processing Record 191 | lazaro cardenas
# Processing Record 192 | palabuhanratu
# City not found. Skipping...
# Processing Record 193 | pevek
# Processing Record 194 | artyk
# City not found. Skipping...
# Processing Record 195 | ahipara
# Processing Record 196 | monzon
# Processing Record 197 | la ferte-bernard
# Processing Record 198 | tuktoyaktuk
# Processing Record 199 | iraquara
# Processing Record 200 | nampula
# Processing Record 201 | camacha
# Processing Record 202 | hofn
# Processing Record 203 | kiama
# Processing Record 204 | karauzyak
# City not found. Skipping...
# Processing Record 205 | panaba
# Processing Record 206 | vilhena
# Processing Record 207 | norman wells
# Processing Record 208 | suchilquitongo
# City not found. Skipping...
# Processing Record 209 | hithadhoo
# Processing Record 210 | mantua
# Processing Record 211 | husavik
# Processing Record 212 | severo-kurilsk
# Processing Record 213 | high level
# Processing Record 214 | gorkovskoye
# City not found. Skipping...
# Processing Record 215 | santa maria
# Processing Record 216 | biltine
# Processing Record 217 | porto nacional
# Processing Record 218 | oloron-sainte-marie
# Processing Record 219 | angoram
# Processing Record 220 | saint-philippe
# Processing Record 221 | bathsheba
# Processing Record 222 | chara
# Processing Record 223 | varhaug
# Processing Record 224 | lebedyn
# Processing Record 225 | hay river
# Processing Record 226 | anchorage
# Processing Record 227 | carupano
# Processing Record 228 | satitoa
# City not found. Skipping...
# Processing Record 229 | mahon
# Processing Record 230 | mirabad
# Processing Record 231 | caravelas
# Processing Record 232 | praia
# Processing Record 233 | kuusamo
# Processing Record 234 | new norfolk
# Processing Record 235 | san andres
# Processing Record 236 | vao
# Processing Record 237 | longyearbyen
# Processing Record 238 | sorland
# Processing Record 239 | eyl
# Processing Record 240 | ivybridge
# Processing Record 241 | atar
# Processing Record 242 | tumannyy
# City not found. Skipping...
# Processing Record 243 | khatanga
# Processing Record 244 | skibbereen
# Processing Record 245 | ust-maya
# Processing Record 246 | lopatyn
# Processing Record 247 | machilipatnam
# Processing Record 248 | bossembele
# City not found. Skipping...
# Processing Record 249 | sobolevo
# Processing Record 250 | taoudenni
# Processing Record 251 | misterbianco
# Processing Record 252 | alofi
# Processing Record 253 | ormara
# Processing Record 254 | port-de-bouc
# Processing Record 255 | santa luzia
# Processing Record 256 | itupiranga
# Processing Record 257 | torbat-e jam
# Processing Record 258 | poddorye
# Processing Record 259 | port lincoln
# Processing Record 260 | south lake tahoe
# Processing Record 261 | san javier
# Processing Record 262 | kavieng
# Processing Record 263 | atsiki
# City not found. Skipping...
# Processing Record 264 | lagoa
# Processing Record 265 | uddevalla
# Processing Record 266 | sturgeon falls
# Processing Record 267 | batemans bay
# Processing Record 268 | nauta
# Processing Record 269 | dunmore town
# Processing Record 270 | caucaia
# Processing Record 271 | makakilo city
# Processing Record 272 | bonavista
# Processing Record 273 | cidreira
# Processing Record 274 | tsihombe
# City not found. Skipping...
# Processing Record 275 | upernavik
# Processing Record 276 | sokoni
# Processing Record 277 | georgetown
# Processing Record 278 | nome
# Processing Record 279 | san quintin
# Processing Record 280 | annau
# Processing Record 281 | chuy
# Processing Record 282 | hasaki
# Processing Record 283 | paamiut
# Processing Record 284 | moree
# Processing Record 285 | noumea
# Processing Record 286 | santa rosa
# Processing Record 287 | dawlatabad
# Processing Record 288 | fort nelson
# Processing Record 289 | sao joao da barra
# Processing Record 290 | kuytun
# Processing Record 291 | aklavik
# Processing Record 292 | rosario oeste
# Processing Record 293 | zhangjiakou
# Processing Record 294 | rawson
# Processing Record 295 | rantepao
# Processing Record 296 | novobirilyussy
# Processing Record 297 | koshurnikovo
# Processing Record 298 | hailar
# Processing Record 299 | celestun
# Processing Record 300 | sechura
# Processing Record 301 | sao felix do xingu
# Processing Record 302 | san cristobal
# Processing Record 303 | xinzhi
# Processing Record 304 | teya
# Processing Record 305 | tiksi
# Processing Record 306 | mar del plata
# Processing Record 307 | carahue
# Processing Record 308 | samarai
# Processing Record 309 | halifax
# Processing Record 310 | port hedland
# Processing Record 311 | ribeira grande
# Processing Record 312 | sola
# Processing Record 313 | birjand
# Processing Record 314 | santa cruz de tenerife
# Processing Record 315 | primorsk
# Processing Record 316 | iqaluit
# Processing Record 317 | tahta
# Processing Record 318 | chifeng
# Processing Record 319 | namibe
# Processing Record 320 | karasjok
# Processing Record 321 | cayenne
# Processing Record 322 | vredendal
# Processing Record 323 | beyneu
# Processing Record 324 | macomb
# Processing Record 325 | ambilobe
# Processing Record 326 | qaqortoq
# Processing Record 327 | coquimbo
# Processing Record 328 | deputatskiy
# Processing Record 329 | tutoia
# Processing Record 330 | yulara
# Processing Record 331 | kleck
# City not found. Skipping...
# Processing Record 332 | klaksvik
# Processing Record 333 | cabra
# Processing Record 334 | tabou
# Processing Record 335 | tocopilla
# Processing Record 336 | birao
# Processing Record 337 | aitape
# Processing Record 338 | comodoro rivadavia
# Processing Record 339 | goundam
# Processing Record 340 | chabahar
# Processing Record 341 | aflu
# City not found. Skipping...
# Processing Record 342 | touros
# Processing Record 343 | mountain home
# Processing Record 344 | laguna
# Processing Record 345 | lae
# Processing Record 346 | talnakh
# Processing Record 347 | teguise
# Processing Record 348 | shurugwi
# Processing Record 349 | harper
# Processing Record 350 | baghdad
# Processing Record 351 | sorvag
# City not found. Skipping...
# Processing Record 352 | gerede
# Processing Record 353 | katsuura
# Processing Record 354 | torbay
# Processing Record 355 | vulcan
# Processing Record 356 | westport
# Processing Record 357 | sitka
# Processing Record 358 | izhma
# Processing Record 359 | marsh harbour
# Processing Record 360 | wanning
# Processing Record 361 | sinnamary
# Processing Record 362 | nalut
# Processing Record 363 | dubenskiy
# City not found. Skipping...
# Processing Record 364 | hwange
# Processing Record 365 | jalu
# Processing Record 366 | tuatapere
# Processing Record 367 | yabelo
# Processing Record 368 | wahran
# City not found. Skipping...
# Processing Record 369 | belaya gora
# Processing Record 370 | rio grande
# Processing Record 371 | menongue
# Processing Record 372 | belomorsk
# Processing Record 373 | nadvoitsy
# Processing Record 374 | nizhniye vyazovyye
# Processing Record 375 | avera
# Processing Record 376 | niltepec
# Processing Record 377 | beira
# Processing Record 378 | vaitupu
# City not found. Skipping...
# Processing Record 379 | curup
# Processing Record 380 | buraydah
# Processing Record 381 | goderich
# Processing Record 382 | boyolangu
# Processing Record 383 | avallon
# Processing Record 384 | flin flon
# Processing Record 385 | maniwaki
# Processing Record 386 | aswan
# Processing Record 387 | karaul
# City not found. Skipping...
# Processing Record 388 | hamilton
# Processing Record 389 | denizli
# Processing Record 390 | wilmington
# Processing Record 391 | atasu
# Processing Record 392 | vostok
# Processing Record 393 | khasan
# Processing Record 394 | pitea
# Processing Record 395 | grindavik
# Processing Record 396 | pacific grove
# Processing Record 397 | hvide sande
# Processing Record 398 | sebinkarahisar
# Processing Record 399 | adrar
# Processing Record 400 | arman
# Processing Record 401 | abashiri
# Processing Record 402 | lander
# Processing Record 403 | benguela
# Processing Record 404 | salalah
# Processing Record 405 | ugoofaaru
# Processing Record 406 | grand river south east
# City not found. Skipping...
# Processing Record 407 | yialos
# City not found. Skipping...
# Processing Record 408 | esperance
# Processing Record 409 | bontang
# Processing Record 410 | teguldet
# Processing Record 411 | bababe
# City not found. Skipping...
# Processing Record 412 | manicore
# Processing Record 413 | kichera
# Processing Record 414 | pochutla
# Processing Record 415 | marabba
# Processing Record 416 | ossora
# Processing Record 417 | panuco
# Processing Record 418 | abu kamal
# Processing Record 419 | inongo
# Processing Record 420 | brokopondo
# Processing Record 421 | koscierzyna
# Processing Record 422 | berlevag
# Processing Record 423 | campo maior
# Processing Record 424 | paranaiba
# Processing Record 425 | yakeshi
# Processing Record 426 | mitsamiouli
# Processing Record 427 | berdigestyakh
# Processing Record 428 | gazanjyk
# Processing Record 429 | suluktu
# Processing Record 430 | nishihara
# Processing Record 431 | teahupoo
# Processing Record 432 | havre-saint-pierre
# Processing Record 433 | ilulissat
# Processing Record 434 | wichian buri
# Processing Record 435 | voyvozh
# Processing Record 436 | coahuayana
# Processing Record 437 | otavi
# Processing Record 438 | batagay
# Processing Record 439 | panguipulli
# Processing Record 440 | kaberamaido
# Processing Record 441 | bengkulu
# Processing Record 442 | srednekolymsk
# Processing Record 443 | halalo
# City not found. Skipping...
# Processing Record 444 | konza
# Processing Record 445 | mouriai
# City not found. Skipping...
# Processing Record 446 | bolungarvik
# City not found. Skipping...
# Processing Record 447 | cairns
# Processing Record 448 | jambi
# Processing Record 449 | price
# Processing Record 450 | pangnirtung
# Processing Record 451 | revyakino
# Processing Record 452 | inuvik
# Processing Record 453 | vila franca do campo
# Processing Record 454 | mollendo
# Processing Record 455 | jiwani
# Processing Record 456 | castres
# Processing Record 457 | mehran
# Processing Record 458 | kununurra
# Processing Record 459 | khingansk
# Processing Record 460 | sacramento
# Processing Record 461 | torrington
# Processing Record 462 | york
# Processing Record 463 | baruun-urt
# Processing Record 464 | amudalavalasa
# Processing Record 465 | biak
# Processing Record 466 | provideniya
# Processing Record 467 | college
# Processing Record 468 | schrems
# Processing Record 469 | awjilah
# Processing Record 470 | roma
# Processing Record 471 | sao gabriel da cachoeira
# Processing Record 472 | balykshi
# Processing Record 473 | savannah bight
# Processing Record 474 | kalmunai
# Processing Record 475 | santeramo in colle
# Processing Record 476 | port moresby
# Processing Record 477 | axim
# Processing Record 478 | melfi
# Processing Record 479 | sabla
# Processing Record 480 | kaeo
# Processing Record 481 | zolotinka
# City not found. Skipping...
# Processing Record 482 | faya
# Processing Record 483 | havoysund
# Processing Record 484 | millinocket
# Processing Record 485 | ngukurr
# City not found. Skipping...
# Processing Record 486 | quthing
# Processing Record 487 | susani
# Processing Record 488 | chagoda
# Processing Record 489 | kargil
# Processing Record 490 | emerald
# Processing Record 491 | tonantins
# Processing Record 492 | santa cruz
# Processing Record 493 | linchuan
# City not found. Skipping...
# Processing Record 494 | bojnurd
# Processing Record 495 | devils lake
# Processing Record 496 | nanortalik
# Processing Record 497 | waipawa
# Processing Record 498 | yaqui
# Processing Record 499 | alice springs
# Processing Record 500 | tilichiki
# Processing Record 501 | tual
# Processing Record 502 | corinto
# Processing Record 503 | galveston
# Processing Record 504 | kuche
# City not found. Skipping...
# Processing Record 505 | matara
# Processing Record 506 | bambanglipuro
# Processing Record 507 | champerico
# Processing Record 508 | zachepylivka
# Processing Record 509 | dingle
# Processing Record 510 | napierville
# Processing Record 511 | dekar
# Processing Record 512 | mehamn
# Processing Record 513 | jardim
# Processing Record 514 | boksitogorsk
# Processing Record 515 | aykhal
# Processing Record 516 | tawkar
# City not found. Skipping...
# Processing Record 517 | olafsvik
# Processing Record 518 | tessalit
# Processing Record 519 | damghan
# Processing Record 520 | bocaiuva
# Processing Record 521 | kruisfontein
# Processing Record 522 | mindelo
# Processing Record 523 | longlac
# City not found. Skipping...
# Processing Record 524 | parambu
# Processing Record 525 | maceio
# Processing Record 526 | poum
# Processing Record 527 | ust-kuyga
# Processing Record 528 | jaisalmer
# Processing Record 529 | cravinhos
# Processing Record 530 | sterling
# Processing Record 531 | yaan
# Processing Record 532 | skiros
# City not found. Skipping...
# Processing Record 533 | smithers
# Processing Record 534 | pinega
# Processing Record 535 | dembi dolo
# Processing Record 536 | lithakia
# Processing Record 537 | hambantota
# Processing Record 538 | mundo nuevo
# Processing Record 539 | port macquarie
# Processing Record 540 | vestmannaeyjar
# Processing Record 541 | jacareacanga
# Processing Record 542 | sibu
# Processing Record 543 | moron
# Processing Record 544 | grand centre
# City not found. Skipping...
# Processing Record 545 | la ronge
# Processing Record 546 | minador do negrao
# Processing Record 547 | esil
# Processing Record 548 | port keats
# Processing Record 549 | mogadishu
# Processing Record 550 | leningradskiy
# Processing Record 551 | mayo
# Processing Record 552 | tiznit
# Processing Record 553 | san-pedro
# Processing Record 554 | paluan
# Processing Record 555 | marhaura
# Processing Record 556 | brae
# Processing Record 557 | boxmeer
# Processing Record 558 | hohhot
# Processing Record 559 | kurumkan
# Processing Record 560 | broome
# Processing Record 561 | sao joao da ponte
# Processing Record 562 | norrtalje
# Processing Record 563 | diffa
# Processing Record 564 | bilibino
# Processing Record 565 | papasquiaro
# City not found. Skipping...
# Processing Record 566 | qinhuangdao
# Processing Record 567 | lavrentiya
# Processing Record 568 | wanaka
# Processing Record 569 | san policarpo
# Processing Record 570 | isangel
# Processing Record 571 | kusti
# Processing Record 572 | bathurst
# Processing Record 573 | ola
# Processing Record 574 | nioro
# Processing Record 575 | zhigalovo
# Processing Record 576 | gazojak
# Processing Record 577 | rio bueno
# Processing Record 578 | tombouctou
# Processing Record 579 | areia branca
# Processing Record 580 | derzhavinsk
# Processing Record 581 | santa engracia
# Processing Record 582 | nuevitas
# Processing Record 583 | waitati
# Processing Record 584 | burkhala
# City not found. Skipping...
# Processing Record 585 | jaciara
# Processing Record 586 | nyaunglebin
# Processing Record 587 | saint anthony
# Processing Record 588 | mondovi
# Processing Record 589 | tepexpan
# Processing Record 590 | gurskoye
# City not found. Skipping...
# Processing Record 591 | valleyview
# Processing Record 592 | jardim de piranhas
# Processing Record 593 | aakirkeby
# City not found. Skipping...
# Processing Record 594 | marcona
# City not found. Skipping...
# Processing Record 595 | shangrao
# Processing Record 596 | bella union
# Processing Record 597 | gushikawa
# Processing Record 598 | gushi
# Processing Record 599 | iquique
# Processing Record 600 | galich
# Processing Record 601 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 602 | aksu
# Processing Record 603 | ustka
# Processing Record 604 | lumsden
# Processing Record 605 | punta cardon
# Processing Record 606 | wenling
# Processing Record 607 | evensk
# Processing Record 608 | amapa
# Processing Record 609 | praya
# Processing Record 610 | dubbo
# Processing Record 611 | maragogi
# Processing Record 612 | moba
# Processing Record 613 | zyryanovsk
# Processing Record 614 | maloyaz
# City not found. Skipping...
# Processing Record 615 | erzurum
# Processing Record 616 | najran
# Processing Record 617 | ascension
# Processing Record 618 | dubai
# Processing Record 619 | estelle
# Processing Record 620 | nyagan
# Processing Record 621 | lagos
# Processing Record 622 | ancud
# Processing Record 623 | skegness
# Processing Record 624 | sentyabrskiy
# City not found. Skipping...
# Processing Record 625 | luba
# Processing Record 626 | mumbwa
# Processing Record 627 | port blair
# Processing Record 628 | zabid
# Processing Record 629 | seydi
# Processing Record 630 | ketchikan
# Processing Record 631 | ritterhude
# Processing Record 632 | kozhva
# Processing Record 633 | gulshat
# City not found. Skipping...
# Processing Record 634 | mount clemens
# Processing Record 635 | acara
# Processing Record 636 | launceston
# Processing Record 637 | kavaratti
# Processing Record 638 | te anau
# Processing Record 639 | nhulunbuy
# Processing Record 640 | inhambane
# Processing Record 641 | zeya
# Processing Record 642 | nokaneng
# Processing Record 643 | bida
# Processing Record 644 | rawannawi
# City not found. Skipping...
# Processing Record 645 | aripuana
# Processing Record 646 | sambava
# Processing Record 647 | tres arroyos
# Processing Record 648 | cotonou
# Processing Record 649 | cockburn town
# Processing Record 650 | mecca
# Processing Record 651 | bubaque
# Processing Record 652 | manta
# Processing Record 653 | drayton valley
# Processing Record 654 | cusco
# Processing Record 655 | vytegra
# Processing Record 656 | jijiga
# Processing Record 657 | severnoye
# Processing Record 658 | agadez
# Processing Record 659 | agadir
# Processing Record 660 | oga
# Processing Record 661 | rincon
# Processing Record 662 | goma
# Processing Record 663 | kalabo
# Processing Record 664 | araure
# Processing Record 665 | ous
# Processing Record 666 | dori
# Processing Record 667 | lucea
# Processing Record 668 | gasa
# Processing Record 669 | buala
# Processing Record 670 | verkhnevilyuysk
# Processing Record 671 | coburg
# Processing Record 672 | juba
# Processing Record 673 | pisco
# Processing Record 674 | guangyuan
# Processing Record 675 | vila
# Processing Record 676 | kualakapuas
# Processing Record 677 | keita
# Processing Record 678 | luena
# Processing Record 679 | macon
# Processing Record 680 | kharp
# Processing Record 681 | aksarka
# Processing Record 682 | okakarara
# Processing Record 683 | lolua
# City not found. Skipping...
# Processing Record 684 | sorong
# Processing Record 685 | hirara
# Processing Record 686 | mago
# Processing Record 687 | chandrapur
# Processing Record 688 | severodvinsk
# Processing Record 689 | oruro
# Processing Record 690 | santander
# Processing Record 691 | solnechnyy
# Processing Record 692 | waycross
# Processing Record 693 | pimentel
# Processing Record 694 | coihaique
# Processing Record 695 | beloha
# Processing Record 696 | kangaatsiaq
# Processing Record 697 | serenje
# Processing Record 698 | chernogolovka
# Processing Record 699 | moerai
# Processing Record 700 | san lucas
# Processing Record 701 | kapoeta
# Processing Record 702 | les cayes
# Processing Record 703 | ust-uda
# Processing Record 704 | apatfalva
# Processing Record 705 | cam pha
# City not found. Skipping...
# Processing Record 706 | rio gallegos
# Processing Record 707 | hare bay
# Processing Record 708 | ouadda
# Processing Record 709 | vila velha
# Processing Record 710 | saint-francois
# Processing Record 711 | kaduy
# Processing Record 712 | ribeira brava
# Processing Record 713 | medicine hat
# Processing Record 714 | mareeba
# Processing Record 715 | natal
# Processing Record 716 | doha
# Processing Record 717 | kirakira
# Processing Record 718 | zheleznodorozhnyy
# Processing Record 719 | adre
# Processing Record 720 | dakar
# Processing Record 721 | chapais
# Processing Record 722 | mendi
# Processing Record 723 | shingu
# Processing Record 724 | nobres
# Processing Record 725 | kenai
# Processing Record 726 | uray
# Processing Record 727 | alibag
# Processing Record 728 | barra do garcas
# Processing Record 729 | cumaribo
# City not found. Skipping...
# Processing Record 730 | tabas
# Processing Record 731 | hastings
# Processing Record 732 | cortes
# Processing Record 733 | tahoua
# Processing Record 734 | freeport
# Processing Record 735 | hihifo
# City not found. Skipping...
# Processing Record 736 | vanderhoof
# Processing Record 737 | porto novo
# Processing Record 738 | plettenberg bay
# Processing Record 739 | richards bay
# Processing Record 740 | marrakesh
# Processing Record 741 | huilong
# Processing Record 742 | bella vista
# Processing Record 743 | abapo
# Processing Record 744 | nenjiang
# Processing Record 745 | sibolga
# Processing Record 746 | maua
# Processing Record 747 | tuttlingen
# Processing Record 748 | babstovo
# Processing Record 749 | aksay
# Processing Record 750 | itoman
# Processing Record 751 | colotlan
# Processing Record 752 | hokitika
# Processing Record 753 | swan hill
# Processing Record 754 | springbok
# Processing Record 755 | cururupu
# Processing Record 756 | cangas
# Processing Record 757 | dongsheng
# Processing Record 758 | baijiantan
# Processing Record 759 | geraldton
# Processing Record 760 | manokwari
# Processing Record 761 | effingham
# Processing Record 762 | bilma
# Processing Record 763 | thinadhoo
# Processing Record 764 | rokytne
# Processing Record 765 | gizo
# Processing Record 766 | xuanzhou
# Processing Record 767 | catuday
# Processing Record 768 | shakhtinsk
# Processing Record 769 | bend
# Processing Record 770 | oktyabrskiy
# Processing Record 771 | olinda
# Processing Record 772 | tshikapa
# Processing Record 773 | kamenskoye
# City not found. Skipping...
# Processing Record 774 | manzhouli
# Processing Record 775 | aguas verdes
# Processing Record 776 | kedrovyy
# Processing Record 777 | jacksonville
# Processing Record 778 | labuhan
# Processing Record 779 | itarema
# Processing Record 780 | zheshart
# Processing Record 781 | xapuri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Lindon      US  40.3433 -111.7208     53.51        51          75
# 1        Rikitea      PF -23.1203 -134.9692     73.29        73          99
# 2  Sioux Lookout      CA  50.1001  -91.9170     68.38        77           1
# 3       Barcelos      PT  41.5388   -8.6151     58.84        70          66
# 4        Ushuaia      AR -54.8000  -68.3000     38.86        87          75
#
#    Wind Speed Current Description
# 0        1.01       broken clouds
# 1       17.25     overcast clouds
# 2        6.91           clear sky
# 3        3.71       broken clouds
# 4       12.66          light rain

# %%
city_data_df['Lat'].round(decimals = 2)
city_data_df['Lng'].round(decimals = 2)
pd.options.display.float_format = "{:,.2f}".format
city_data_df
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Lindon      US  40.34 -111.72     53.51        51          75
# 1          Rikitea      PF -23.12 -134.97     73.29        73          99
# 2    Sioux Lookout      CA  50.10  -91.92     68.38        77           1
# 3         Barcelos      PT  41.54   -8.62     58.84        70          66
# 4          Ushuaia      AR -54.80  -68.30     38.86        87          75
# ..             ...     ...    ...     ...       ...       ...         ...
# 709   Jacksonville      US  30.33  -81.66     75.97        81           1
# 710        Labuhan      ID  -6.88  112.21     89.37        55           8
# 711        Itarema      BR  -2.92  -39.92     78.46        84          30
# 712       Zheshart      RU  62.07   49.57     44.10        91         100
# 713         Xapuri      BR -10.65  -68.50     73.29        86          64
#
#      Wind Speed Current Description
# 0          1.01       broken clouds
# 1         17.25     overcast clouds
# 2          6.91           clear sky
# 3          3.71       broken clouds
# 4         12.66          light rain
# ..          ...                 ...
# 709        4.61                mist
# 710        7.54           clear sky
# 711       13.65    scattered clouds
# 712        7.61     overcast clouds
# 713        2.66       broken clouds
#
# [714 rows x 9 columns]

# %%
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
